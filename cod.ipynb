# %%
import pandas as pd

# %%
traffic = pd.read_csv("original data/trafficlist_forcountry.csv")
forest = pd.read_csv("original data/forest-cover-v1.csv")
air_city = pd.read_csv("original data/aap_air_quality_database_2018_v14.csv", skiprows=2)
air_country = pd.read_csv("original data/【12】GlobalPM25-1998-2022.csv")
weather = pd.read_csv("original data/GlobalWeatherRepository.csv")

# %%
#Clean data -remove the attribuites which are useless
#traffic
traffic = traffic.drop(columns=['Population'])
traffic = traffic.drop(columns=['Ref'])
traffic.head()
# Out:
#           Location Rate[per 1000] Vehicles  Year
# 0       San Marino          1,606   53,940  2024
# 1    Guernsey (UK)          1,389   88,532  2022
# 2   Gibraltar (UK)          1,293   48,641  2022
# 3      Jersey (UK)          1,234  127,911  2023
# 4          Andorra          1,214   98,183  2023

# %%
#Clean data -remove the attribuites which are useless
#air_city
air_city = air_city.drop(columns=["Reference for air quality","iso3","Database version (year)","Temporal coverage.1","status","Number and type of monitoring stations","note on converted PM2.5","Annual mean, ug/m3","Temporal coverage","note on converted PM10"])

air_city.head()
# Out:
#                   Region    Country           City/Town  Year  \
# 0          Europe (LMIC)    Albania              Tirana  2013
# 1          Europe (LMIC)    Albania               Vrith  2015
# 2           Europe (HIC)    Andorra  Escaldes-Engordany  2017
# 3  Western Pacific (HIC)  Australia            Adelaide  2016
# 4  Western Pacific (HIC)  Australia            Brisbane  2016
#
#    Annual mean, ug/m3.1
# 0                    16
# 1                    13
# 2                    10
# 3                     7
# 4                     7

# %%
#Clean data -remove the attribuites which are useless
#air_country
air_country = air_country.drop(columns=["% pop >= 5 ug/m3 [%]","% pop >= 10 ug/m3 [%]","% pop >= 15 ug/m3 [%]","% pop >= 30 ug/m3 [%]","% pop >= 35 ug/m3 [%]","% pop >= 40 ug/m3 [%]","% pop >= 45 ug/m3 [%]","% pop >= 50 ug/m3 [%]","% pop >= 55 ug/m3 [%]","% pop >= 60 ug/m3 [%]"])
air_country.head()
# Out:
#   Region  Year  Population-Weighted PM2.5 [ug/m3]  \
# 0  Aruba  1998                                9.5
# 1  Aruba  1999                               10.1
# 2  Aruba  2000                               10.2
# 3  Aruba  2001                               10.6
# 4  Aruba  2002                               10.5
#
#    Geographic-Mean PM2.5 [ug/m3]  Population Coverage [%]  \
# 0                            9.3                    100.0
# 1                            9.9                    100.0
# 2                           10.0                    100.0
# 3                           10.4                    100.0
# 4                           10.3                    100.0
#
#    Geographic Coverage [%]  Total Population [million people]  \
# 0                    100.0                              0.088
# 1                    100.0                              0.088
# 2                    100.0                              0.088
# ...

# %%
#Clean data -remove the attribuites which are useless
#forest
forest = forest.drop(columns=["Population Growth Rate","World Population Percentage"])
forest.head()
# Out:
#   Country Name           Capital      Continent  Area (km²)  \
# 0        Aruba        Oranjestad  North America         180
# 1  Afghanistan             Kabul           Asia      652230
# 2       Angola            Luanda         Africa     1246700
# 3      Albania            Tirana         Europe       28748
# 4      Andorra  Andorra la Vella         Europe         468
#
#    Population Density (per km²)  Population Rank  Forest Area 1990  \
# 0                      591.3611              198          2.333333
# 1                       63.0587               36          1.850994
# 2                       28.5466               42         63.578070
# 3                       98.8702              138         28.788321
# 4                      170.5641              203         34.042553
#
#    Forest Area 1991  Forest Area 1992  Forest Area 1993  ...  \
# 0          2.333333          2.333333          2.333333  ...
# 1          1.850994          1.850994          1.850994  ...
# ...

# %%
#Clean data -remove the attribuites which are useless
#GlobalWeather

weather = weather.drop(columns=["Population Growth Rate","World Population Percentage"])
weather.head()
